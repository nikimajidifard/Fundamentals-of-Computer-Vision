# %% [markdown]
# # Question 1
# ## part 1

# %%
#libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #### read image with matplotlib

# %%
#read image with matplitlib 
img = plt.imread('Q1.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# #### read and show image with opencv2

# %%
img2 = cv2.imread('Q1.jpg')
#convert bgr to rgb 
cv2.imshow('image',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### show image with matplotlib using opencv to read

# %%
#show image with opencv read image
plt.imshow(img2)
plt.axis('off')
# Out:
# (-0.5, 1019.5, 679.5, -0.5)

# %% [markdown]
# #### convert bgr to rgb

# %%
plt.imshow(cv2.cvtColor(img2 ,  cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## part 2

# %% [markdown]
# #### matplotlib

# %%
width , height , channels= img2.shape
print('width :', width , ',height:',  height ,',channels:' , channels )
# Out:
# width : 680 ,height: 1020 ,channels: 3

# %% [markdown]
# #### cv2

# %%
width , height , channels= img.shape
print('width :', width , ',height:',  height ,',channels:' , channels )
# Out:
# width : 680 ,height: 1020 ,channels: 3

# %% [markdown]
# ## Part 3

# %% [markdown]
# create new directory

# %%
# Directory
directory = "new_Q1"

parent_dir = "Q1"

path = os.path.join(parent_dir, directory)

try:
	os.makedirs(path, exist_ok = True)
	print("Directory '%s' created successfully" %directory)
except OSError as error:
	print("Directory '%s' can not be created")
# Out:
# Directory 'new_Q1' created successfully

# %%
for filename in os.scandir('Q1'):
    if filename.is_file():
        path = filename.path
        img = cv2.imread(path)
        img_gray = cv2.cvtColor(img ,  cv2.COLOR_BGR2GRAY)
        img_name = path.split('\\')[1].split('.')[0]
        cv2.imwrite(rf'Q1\\new_Q1\\{img_name}_Gray.jpeg' , img_gray)
        file = open(rf'Q1\\new_Q1\\{img_name}_file',"a")
        file.writelines(str(img.shape))
